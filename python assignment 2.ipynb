# %%
for i in range(5):
    for j in range(i+1):
        print(".",end = "")
    print("")
for i in range(5): 
    for j in range(4-i):
        print(".",end = "")
    print("")
# Out:
# .
# ..
# ...
# ....
# .....
# ....
# ...
# ..
# .

# %%
input_word = input("Enter you input: ")
print(input_word[::-1])
# Out:
# Enter you input: how are you
# uoy era woh
